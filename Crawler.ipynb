# %%
import requests
import time
from bs4 import BeautifulSoup
import json
from urllib.parse import urlparse,urlsplit
import urllib.robotparser
import re

# %%
import urllib.request
from bs4 import BeautifulSoup
from bs4.element import Comment

# %%
keywords = ['American Revolution', 'Great Britain', 'Colonies', 'John Adams', 'Benjamin Franklin', 'Alexander Hamilton',
            'John Jay', 'Thomas Jefferson', 'James Madison', 'George Washington', 'Declaration', 'Independence', 'Declaration of Independence',
           'Constitution', 'Treaty of Paris', '1783', '1777', '1780', 'The Federalist Papers', 'Signers',
           'Founding Fathers', 'Fathers', 'Congress', 'British', 'thirteen colonies', 'John Hancock', 'Parliament',
           'Congress of the Confederation', 'United States Congress', '1775-83', 'France', 'rebels', 'colonial', 'colonists',
           'Stamp Act', ' Townshend Tariffs', '1765', '1767', 'Tea Act', '1773', 'Boston Massacre', 'Benedict Arnold',
           'Ticonderoga', 'Saratoga', 'Battle of Saratoga', 'Treaty of Paris',
           'conflict', 'Charleston', 'Quebec', 'Cornwalli', 'Boston Tea Party', 'Patriots', 'Loyalist', 'Thomas Gage',
           'Charleston']

# %%
# //https://stackoverflow.com/questions/1936466/beautifulsoup-grab-visible-webpage-text
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

# %%
# req = urllib.request.urlopen('https://en.wikipedia.org/wiki/Okapi_BM25')

# %%
# req.read()

# %%
# soup = BeautifulSoup(req.read(), 'html.parser')

# %%
# import requests
# import re

# # page = requests.get("http://en.wikipedia.org/wiki/Founding_Fathers_of_the_United_States")
# page = requests.get("http://www.revolutionary-war.net/causes-of-the-american-revolution.html")
# page

# %%
# page.content

# %%
# soup = BeautifulSoup(page.content, 'html.parser')

# %%
# print(soup.prettify())

# %%
# list(soup.children)

# %%
# links = []
 
# for link in soup.findAll('a', href = True):
#     links.append(link.get('href'))
    
# print(links)

# %%
# len(links)

# %%
# len(can_link)

# %%
# can_link

# %%
# link1 = ['HTTP://www.Example.com/SomeFile.html', 
#          'http://www.example.com:80', 
#          'http://www.example.com/a.html#anything', 
#          '../c.html', 
#          'http://www.example.com//a.html',
#         'http://www.example.com//b//a.html',
#         '/c.html',
#         '..//d.html',
#         'e.html',
#         '#frag']

# %%
# parent_url1 = 'http://www.example.com/a/b.html'
# parent_url = 'http://en.wikipedia.org/wiki/Founding_Fathers_of_the_United_States'
# p = "http://www.revolutionary-war.net/causes-of-the-american-revolution.html"

# %%
# ignore_list = ['http://en.wikipedia.org/wiki/Main_Page',
#            'http://en.wikipedia.org/w/index.php', 
#            'http://en.m.wikipedia.org/w/index.php', 
#            'https://en.wikipedia.org/wiki/Main_Page',           
#            "http://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License",
#            "http://creativecommons.org/licenses/by-sa/3.0/",
#            "http://wikimediafoundation.org/wiki/Terms_of_Use",
#            "http://wikimediafoundation.org/wiki/Privacy_policy",
#            "http://www.wikimediafoundation.org/",
#            "https://foundation.wikimedia.org/wiki/Privacy_policy",
#            "http://en.wikipedia.org/wiki/Wikipedia:About",
#            "http://en.wikipedia.org/wiki/Wikipedia:General_disclaimer",
#            "http://en.wikipedia.org/wiki/Wikipedia:Contact_us",
#            "https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute",
#            "https://foundation.wikimedia.org/wiki/Cookie_statement",
#            "https://foundation.wikimedia.org/",
#            "http://www.mediawiki.org/",
#            "https://en.wikipedia.org/w/index.php",
#               "https://feedly.com/",
#                "http://add.my.yahoo.com/rss",
#                "http://my.msn.com/addtomymsn.aspx",
#                "http://www.public-domain-image.com",
#                "http://commons.wikimedia.org/wiki/Main_Page"
 
#               ]

# %%
ignore_extensions = ['jpg', 'png', 'jif', 'svg', 'jpeg', 'pdf', 'zip', 'gz' , 'tar', 'rar', 'gzip' , 'mobi']

# %%
def Canonicalization_team(parenturl , url):
   
    url = urlsplit(url).geturl()
    url = url.split("?")[0]

   
    if url.find("http") != - 1 or url.find("HTTP") != - 1 or url.find("https") != - 1 or url.find("HTTPs") != -1:
        temp = url.split("//",1)
        temp[1] = temp[1].replace("//" , "/")       
        if temp[1].find("#") != -1:
            temp[1] = temp[1].split('#')[0]            
        temp_part = temp[1].split("/", 1)

        if temp_part[0].find(":") != -1:
            temp_part[0] = temp_part[0].split(":")[0]
       
        if(len(temp_part) > 1):
            return (temp[0].lower() + "//" + temp_part[0].lower() + "/" + temp_part[1])
        return (temp[0].lower() + "//" + temp_part[0].lower() + "/" )
       
    elif url.find("..") != -1:
        temp = url.split("..")
        temp[1] = temp[1].replace("//" , "/")
        if temp[1].find("#") != -1:
            temp[1] = temp[1].split('#')[0]
        parentTemp = parenturl.split("//")
        parentTemp_part = parentTemp[1].split("/", 1)
        return (parentTemp[0].lower() + "//" + parentTemp_part[0].lower() + temp[1])

    else:
        if url.find("#") != -1:
            url = url.split('#')[0]
           
        if url.find("//") != -1:
            temp = url.split("//",1)    
            pattern = re.compile("^([a-z0-9]+(-[a-z0-9]+)*\.)+[a-z]{2,}$")
            if pattern.match(temp[1].split("/")[0])  != None:
                temp[1] = temp[1].replace("//" , "/")
                if temp[1].find("#") != -1:
                    temp[1] = temp[1].split('#')[0]            
                temp_part = temp[1].split("/", 1)

                if temp_part[0].find(":") != -1:
                    temp_part[0] = temp_part[0].split(":")[0]
                if(len(temp_part) > 1):
                    return ("http:" + "//" + temp_part[0].lower() + "/" + temp_part[1])
                return ("http:" + "//" + temp_part[0].lower())
               

       
        parentTemp = parenturl.split("//")
        parentTemp_part = parentTemp[1].split("/", 1)
        if(url == ""):
            return -1
        return (parentTemp[0].lower() + "//" + parentTemp_part[0].lower() + url)

# %%
def canonicalization(links, parent_url):
    can_link = []
    for link in links:
        try:
            cano_url = Canonicalization_team(parent_url , link)
            if (cano_url == -1):
                continue
        except:
            continue
        can_link.append(cano_url)
    return can_link
        
#     #     print(link)
#         ext = link.split(".")[-1]
   
#         if ext.lower() in  ignore_extensions:
#             continue
#         o = urlparse(link)
#         cano_url = ''
        
#     #     print(o)
#     #     if(o.port != None):
#     #         print(o.netloc.lower().replace(str(o.port),"").split(":")[0])
    
#         if(o.scheme != ''):
#             cano_url = o.scheme + "://" + o.netloc.lower().split(":")[0] + o.path.replace("//", "/")
#     #         print(cano_url)
#         else:
#             if(o.path != ''):
#                 link_temp = o.path.replace('//', '/').replace("..","")
#     #             print(o)
#     #             print(link_temp)
#                 parent_parse = urlparse(parent_url)
#                 parent_part = parent_parse.scheme + "://" + parent_parse.netloc

#                 if(link_temp[0] == '/'):
#                     cano_url = parent_part + link_temp
#                 else:
#                     cano_url = parent_part + '/' + link_temp
                    
#         #ignore list
#         if cano_url in ignore_list :
#             continue
            
#         # Only english pages on wiki
#         if cano_url.find("wikipedia") != -1 and cano_url.split(".")[0][-2:] != 'en':
#             continue
            
#         # wikipedia blacklists
#         if cano_url.find("http://en.wikipedia.org/wiki/Book") != -1 :
#             continue
#         if cano_url.find("http://en.wikipedia.org/wiki/Category") != -1 :
#             continue
#         if cano_url.find("http://en.wikipedia.org/wiki/Portal") != -1:
#             continue
#         if cano_url.find("https://donate.wikimedia.org") != -1:
#             continue
#         if cano_url.find("http://en.wikipedia.org/wiki/Special:") != -1:
#             continue
#         if cano_url.find("http://en.wikipedia.org/wiki/Special:") != -1:
#             continue
#         if cano_url.find("http://shop.wikimedia.org") != -1:
#             continue
#         if(cano_url.find("https://commons.wikimedia.org/wiki/Category") != -1):
#             continue
#         if(cano_url != ''):
#             can_link.append(cano_url)
#     return can_link

# %%
# link_can = canonicalization(links, parent_url)

# %%
# link_can = canonicalization(links, p)

# %%
# len(link_can)

# %%
# link_can

# %%
link_data = {
    'http://en.wikipedia.org/wiki/Founding_Fathers_of_the_United_States': {
        'inlinks': 1,
        'outlinks': 0,
        'time':1
    },
    
    'http://en.wikipedia.org/wiki/American_Revolutionary_War': {
        'inlinks': 2,
        'outlinks': 0,
        'time':2

    },
    
    'http://www.history.com/topics/american-revolution/american-revolution-history': {
        'inlinks': 3,
        'outlinks': 0,
        'time':3

    }
}

# %%
inlinksList = {
    'http://en.wikipedia.org/wiki/Founding_Fathers_of_the_United_States': [],
        'http://en.wikipedia.org/wiki/American_Revolutionary_War': [],
        'http://www.history.com/topics/american-revolution/american-revolution-history': []
}

# %%
frontier = {
    1: [
        'http://en.wikipedia.org/wiki/Founding_Fathers_of_the_United_States',
        'http://en.wikipedia.org/wiki/American_Revolutionary_War',
        'http://www.history.com/topics/american-revolution/american-revolution-history'
    ]
}

# %%
with open("C:\\Users\\priyu\\Desktop\\NEU\\Information Retrieval\\Assignments\\IR_HW_3\\frontierManagement.json") as output:
    frontier2 = json.load(output)

# %%
frontier = {}

# %%
for level in frontier2:
    frontier[int(level)] = frontier2[level]

# %%
with open("C:\\Users\\priyu\\Desktop\\NEU\\Information Retrieval\\Assignments\\IR_HW_3\\linkData.json") as output:
    link_data = json.load(output)

# %%
with open("C:\\Users\\priyu\\Desktop\\NEU\\Information Retrieval\\Assignments\\IR_HW_3\\inlinksList.json") as output:
    inlinksList = json.load(output)

# %%
domain_time = {}

# %%
link_processed_used = []
link_all_2 = {}

# %%
with open("C:\\Users\\priyu\\Desktop\\NEU\\Information Retrieval\\Assignments\\IR_HW_3\\processedDoc.json") as output:
    link_all_2 = json.load(output)

# %%
for id in link_all_2:
    link_processed_used.append(id)

# %%
s = 0

doc_details= {}
doc_details_id= {}

# %%
s = len(link_processed_used)

# %%
while(len(link_processed_used) <= 20000 ):
    max_inlink = 0
    next_link = ''
    for level in sorted(frontier.keys()):
        
        if(len(frontier[level]) == 0):
            continue
            
        for url in frontier[level]:
            
            if(url in link_all_2):
                frontier[level].remove(url)
                continue
#             print(url)    
            ext = url.split(".")[-1]
                
            if ext in ignore_extensions:
#                 print("ignore", url)
                frontier[level].remove(url)
                continue

                
            if (link_data[url]['inlinks'] > max_inlink):
                max_inlink = link_data[url]['inlinks']
                next_link = url
            elif (link_data[url]['inlinks'] == max_inlink):
                if (link_data[url]['time'] < link_data[next_link]['time']):
                    next_link = url
        break
        
    link_all_2[next_link] = True
    
    try:
        robo = urlparse(next_link)
        
        robo_url = robo.scheme + "://" + robo.netloc.lower() + "/robots.txt"
#         rp = urllib.robotparser.RobotFileParser()
#         rp.set_url(robo_url)
# #         print(next_link)
#         rp.read()
# #         print(rp.can_fetch("*", next_link))
#         if(rp.can_fetch("*", next_link) == False ):
# #             print(next_link)
#             frontier[level].remove(next_link)
#             continue
        
#         print(robo_url)

        domain = robo.scheme + "://" + robo.netloc.lower()
        domain_time[domain] = time.time()
        page = requests.get(next_link)
        page_type = page.headers['Content-Type'].split('/')[0]
        if page_type.lower() != "text":
            frontier[level].remove(next_link)
            continue
    except:
        frontier[level].remove(next_link)
        continue
        
    print(next_link)
    
    
    link_context = BeautifulSoup(page.content, 'html.parser')


    links = []
    for link in link_context.findAll('a', href = True):
        for keyword in keywords:
            if str(link).lower().find(keyword.lower()) != -1:
                links.append(link.get('href'))
                break
                
    parent_url = next_link

    link_can = canonicalization(links, parent_url)
    if (level + 1) not in frontier.keys():
        frontier[level + 1] = []
    frontier[level + 1] = frontier[level + 1] + list(set(link_can))
    for l in list(set(link_can)):
        if l not in link_data.keys():
            link_data[l] = {}
            link_data[l]['inlinks'] = 0
            link_data[l]['time'] = time.time()
            inlinksList[l] = []
        link_data[l]['inlinks'] = link_data[l]['inlinks'] + 1
        inlinksList[l].append(next_link)
    
    link_data[next_link]['outlinks'] = len(list(set(link_can)))
    cleantext = text_from_html(page.content).lower()
    try:
        title = link_context.title.string
    except:
        title = ""
    depth = level
    
#     print(level)
    frontier[level].remove(next_link)
    
# #     key_found = False
# #     for keyword in keywords:
# #         if(cleantext.find(keyword.lower()) != -1):
# #             key_found = True
# #             break
            
# #     if key_found:
    link_processed_used.append(next_link)
    link_info = {
        'url': next_link,
        'cleantext': cleantext,
        'rawdata': str(page.content),
        'outlinks': list(set(link_can)),
        'title': title,
        'depth': depth
        
    }
    with open("C:\\Users\\priyu\\Desktop\\NEU\\Information Retrieval\\Assignments\\IR_HW_3\\files\\doc_" + str(s)+ ".json" , "w") as output:
        json.dump(link_info, output)

    doc_details[s] = next_link
    doc_details_id[next_link] = s
    s = s + 1
    if (s % 1000 == 0):
        with open("C:\\Users\\priyu\\Desktop\\NEU\\Information Retrieval\\Assignments\\IR_HW_3\\frontierManagement.json" , "w") as output:
            json.dump(frontier, output)
        with open("C:\\Users\\priyu\\Desktop\\NEU\\Information Retrieval\\Assignments\\IR_HW_3\\linkData.json" , "w") as output:
            json.dump(link_data, output)
        with open("C:\\Users\\priyu\\Desktop\\NEU\\Information Retrieval\\Assignments\\IR_HW_3\\inlinksList.json" , "w") as output:
            json.dump(inlinksList, output)
        
    
    now = time.time()
#     time.sleep(1)
#     break
    if(now - domain_time[domain] < 1):
        time.sleep(now - domain_time[domain])
    
#     print(text_from_html(page.content))
#     print(level)
#     print(link_can) 
    
    
#             page = requests.get(url)
# Out:
# http://www.bia.homeoffice.gov.uk/britishcitizenship/applying/ceremony/
# https://www.facebook.com/TheBritishMonarchy
# https://en.wikibooks.org/wiki/A_History_of_the_British_Monarchy
# https://www.royal.uk/
# http://en.wikipedia.org/wiki/Legislative_session
# http://www.aph.gov.au/About_Parliament/House_of_Representatives/Powers_practice_and_procedure/Practice6/Practice6HTML
# http://en.wikipedia.org/wiki/File:Medieval_parliament_edward.Jpg
# https://web.archive.org/web/20040104135404/http:/www.parliament.uk/parliamentary_committees/public_administration_select_committee/pasc_19.cfm
# http://www.parliament.uk/parliamentary_committees/public_administration_select_committee/pasc_19.cfm
# http://news.bbc.co.uk/1/hi/programmes/bbc_parliament/6110930.stm
# https://web.archive.org/web/20021119091636/http:/www.parliament.uk/faq/lords_stateopening.cfm
# http://www.parliament.uk/faq/lords_stateopening.cfm
# http://en.wikipedia.org/wiki/Committees_of_the_Scottish_Parliament
# ...

# %%
# frontier

# %%
# link_data

# %%
# for link in link_processed_used:
#     print(link, link_data[link]['time'])

# %%
# next_link
# page = requests.get(next_link)

# %%
# text_from_html(page.content)
